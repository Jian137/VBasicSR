# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy import interpolate

# %%
file = np.load("experiments/train_BasicVSRSS4MSR_IXIPD_x2_norm/visualization/IXI_PD_X2_test/500_train_BasicVSRSS4MSR_IXIPD_x2_norm.npy")

# %%
plt.figure()
plt.imshow(file[:,:,1],cmap='gray')
plt.axis ('off')
# Out:
# (-0.5, 239.5, 239.5, -0.5)

# %%
file = np.load("/home/vipsl416-4-zhanglize/Datasets/IXI/IXI_HR/PD/test_slice_video_norm/500/00000000.npy")

# %%
plt.figure()
plt.imshow(file,cmap='gray')
plt.axis ('off')
# Out:
# (-0.5, 239.5, 239.5, -0.5)

# %% [markdown]
# # test

# %%
LR = np.load("/home/vipsl416-4-zhanglize/Datasets/IXI/IXI_LR/bicubic_2x/PD/test_slice_video_norm/512/00000000.npy")
withoutSO = np.load("/home/vipsl416-4-zhanglize/MSR/SR Code/BasicSR/experiments/train_BasicVSRSSwoSO4MSR_IXIPD_x2_norm/visualization/IXI_PD_X2_test/512_train_BasicVSRSSwoSO4MSR_IXIPD_x2_norm.npy")
SR = np.load("/home/vipsl416-4-zhanglize/MSR/SR Code/BasicSR/experiments/train_BasicVSRSS4MSR_IXIPD_x2_norm/visualization/IXI_PD_X2_test/512_train_BasicVSRSS4MSR_IXIPD_x2_norm.npy")
GT = np.load("/home/vipsl416-4-zhanglize/Datasets/IXI/IXI_HR/PD/test_slice_video/512/00000000.npy")

# %%
plt.subplot(1,4,1)
plt.imshow(LR,cmap='gray')
plt.axis ('off')
plt.subplot(1,4,2)
plt.imshow(withoutSO[:,:,:1],cmap='gray')
plt.axis ('off')
plt.subplot(1,4,3)
plt.imshow(SR[:,:,:1],cmap='gray')
plt.axis ('off')
plt.subplot(1,4,4)
plt.imshow(GT,cmap='gray')
plt.axis ('off')
# Out:
# (-0.5, 239.5, 239.5, -0.5)

# %%
plt.figure()
plt.imshow(withoutSO[:,:,:1],cmap='gray')
plt.axis ('off')
plt.savefig("withoutSO.png",bbox_inches="tight", pad_inches=0.0)

# %%
# FTMSR x2 对比可视化

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy import interpolate

# %%
LR = np.load("/mnt/zlz/Dataset/BraTS18/BraTS_LR/bicubic_2x/flair/test_slice_video_split_2/012_1/00000000.npy")
GT = np.load("/mnt/zlz/Dataset/BraTS18/BraTS_HR/flair/test_slice_video_split_2/012_1/00000000.npy")
